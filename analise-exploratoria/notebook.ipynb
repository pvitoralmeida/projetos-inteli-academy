# %% [markdown]
# # Projeto: Visualização de Dados e Análise Exploratória

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Análise Exploratória

# %%
df = pd.read_csv('student_habits_performance.csv')
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.describe()
# Out:
#              age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  1000.0000           1000.00000         1000.000000    1000.000000
# mean     20.4980              3.55010            2.505500       1.819700
# std       2.3081              1.46889            1.172422       1.075118
# min      17.0000              0.00000            0.000000       0.000000
# 25%      18.7500              2.60000            1.700000       1.000000
# 50%      20.0000              3.50000            2.500000       1.800000
# 75%      23.0000              4.50000            3.300000       2.525000
# max      24.0000              8.30000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %% [markdown]
# ## Visualização de Dados

# %%
# Fazer a plotagem de um boxplot para a coluna 'study_hours_per_day'
plt.figure(figsize=(10, 6))
plt.boxplot(df['study_hours_per_day'])
plt.show()

# %% [markdown]
# Outliers: alguns dados indicam mais que 7 horas e meia de estudo.
#
# Mediana: está mais ou menos na faixa de 3 horas e meia de estudo.
#
# Os dados estão levemente concentrados na faixa inferior dos dados (abaixo de 4 horas de estudo).
#
# A maioria estuda cerca de 4 horas por dia, mas alguns poucos chegam a 7. Isso
# pode indicar que alguns poucos alunos são mais dedicados que a maioria.

# %%
# Fazer a plotagem de um boxplot para a coluna 'sleep_hours'
plt.figure(figsize=(10, 6))
plt.boxplot(df['sleep_hours'])
plt.show()

# %% [markdown]
# Outliers: há um registro de mais de 10 horas de sono.
#
# Mediana: está mais ou menos na faixa de 6 horas e meia de sono.
#
# Os dados estão aparentemente simétricos.
#
# A maioria dorme ao menos 6 horas por dia, mas alguns poucos dormem menos que 4. Isso
# pode indicar que alguns alunos tem dificuldade para dormir.

# %%
# Fazer a plotagem de um bloxpot para a coluna 'mental_health_rating'
plt.figure(figsize=(10, 6))
plt.boxplot(df['mental_health_rating'])
plt.show()

# %% [markdown]
# Outliers: não há outliers.
#
# Mediana: está mais ou menos na faixa de 5 pontos.
#
# Os dados estão bem distribuídos no gráfico.
#
# A maioria tem uma classificação na faixa de 3 a 8, enquanto alguns poucos tem classificações que tendem aos extremos (0 e 10). Isso pode indicar que é raro alcançar níveis extremos de saúde mental, positivos ou negativos.

# %%
# Fazer a plotagem de um boxplot para a coluna 'exam_score'
plt.figure(figsize=(10, 6))
plt.boxplot(df['exam_score'])
plt.show()

# %% [markdown]
# Outliers: há alguns registros de notas abaixo de 30 pontos.
#
# Mediana: está mais ou menos na faixa de 72 pontos no exame.
#
# Os dados estão levemente concentrados na faixa superior dos dados (acima dos 60 pontos).
#
# A maioria dos alunos obtiveram uma nota acima da média (60+), mas alguns obtiveram menos que 30. Isso
# pode indicar que alguns alunos tiveram muita dificuldade com a prova.

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['exam_score'], bins=20, color='blue', edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['mental_health_rating'], bins=10, color='blue', edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['sleep_hours'], bins=10, color='blue', edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['study_hours_per_day'], bins=10, color='blue', edgecolor='black')
plt.show()

# %% [markdown]
# ### Hipótese: A qualidade da internet e da dieta afeta o desempenho dos alunos.

# %%
categorias = ['Average', 'Poor', 'Good']
dados = [df[df['internet_quality'] == cat]['exam_score'] for cat in categorias]

plt.figure(figsize=(10, 6))
plt.boxplot(dados, labels=categorias)
plt.show()
# Out:
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_33180\1604035884.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(dados, labels=categorias)

# %%
categorias = ['Fair', 'Poor', 'Good']
dados = [df[df['diet_quality'] == cat]['exam_score'] for cat in categorias]

plt.figure(figsize=(10, 6))
plt.boxplot(dados, labels=categorias)
plt.show()
# Out:
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_33180\4191711078.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(dados, labels=categorias)

# %% [markdown]
# Aparentemente, uma boa qualidade de internet ou de dieta não impede os alunos de tirarem más notas.

# %% [markdown]
# ### Hipótese: alunos com classificação de saúde mental alta tem boas notas

# %%
df_max_mental_health = df[df['mental_health_rating'] == 10]
plt.figure(figsize=(10, 6))
plt.hist(df_max_mental_health['exam_score'], bins=10, color='blue', edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['mental_health_rating'], df['exam_score'], color='blue')
plt.show()

# %% [markdown]
# Aparentemente, apesar de alunos com boa saúde mental terem majoritariamente boas notas, não é necessário ter boa saúde mental para atingir um bom desempenho.
